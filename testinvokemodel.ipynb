# %%
# %pip install requests numpy pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
# Load Databricks token from file
with open('databricks_token.txt', 'r') as f:
    token = f.read().strip()
os.environ['DATABRICKS_TOKEN'] = token

# %%
# %pip install scikit-learn
from typing import Any


from sklearn.datasets import load_breast_cancer
import numpy as np

# Load the breast cancer dataset
data = load_breast_cancer()

# Create a dictionary with one row (first row) from the dataset
row_dict = {feature: value for feature, value in zip(data.feature_names, data.data[0])}
print(row_dict)
# Out:
# ...
#
# [notice] A new release of pip available: 22.3.1 -> 26.0.1
# [notice] To update, run: python3.11 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# ...

# %%
row_dict = {feature: value for feature, value in zip(data.feature_names, data.data[0])}
print(row_dict)
# Out:
# {np.str_('mean radius'): np.float64(17.99), np.str_('mean texture'): np.float64(10.38), np.str_('mean perimeter'): np.float64(122.8), np.str_('mean area'): np.float64(1001.0), np.str_('mean smoothness'): np.float64(0.1184), np.str_('mean compactness'): np.float64(0.2776), np.str_('mean concavity'): np.float64(0.3001), np.str_('mean concave points'): np.float64(0.1471), np.str_('mean symmetry'): np.float64(0.2419), np.str_('mean fractal dimension'): np.float64(0.07871), np.str_('radius error'): np.float64(1.095), np.str_('texture error'): np.float64(0.9053), np.str_('perimeter error'): np.float64(8.589), np.str_('area error'): np.float64(153.4), np.str_('smoothness error'): np.float64(0.006399), np.str_('compactness error'): np.float64(0.04904), np.str_('concavity error'): np.float64(0.05373), np.str_('concave points error'): np.float64(0.01587), np.str_('symmetry error'): np.float64(0.03003), np.str_('fractal dimension error'): np.float64(0.006193), np.str_('worst radius'): np.float6
# ...

# %%
row_dict
# Out:
# {np.str_('mean radius'): np.float64(17.99),
#  np.str_('mean texture'): np.float64(10.38),
#  np.str_('mean perimeter'): np.float64(122.8),
#  np.str_('mean area'): np.float64(1001.0),
#  np.str_('mean smoothness'): np.float64(0.1184),
#  np.str_('mean compactness'): np.float64(0.2776),
#  np.str_('mean concavity'): np.float64(0.3001),
#  np.str_('mean concave points'): np.float64(0.1471),
#  np.str_('mean symmetry'): np.float64(0.2419),
#  np.str_('mean fractal dimension'): np.float64(0.07871),
#  np.str_('radius error'): np.float64(1.095),
#  np.str_('texture error'): np.float64(0.9053),
#  np.str_('perimeter error'): np.float64(8.589),
#  np.str_('area error'): np.float64(153.4),
#  np.str_('smoothness error'): np.float64(0.006399),
#  np.str_('compactness error'): np.float64(0.04904),
#  np.str_('concavity error'): np.float64(0.05373),
#  np.str_('concave points error'): np.float64(0.01587),
#  np.str_('symmetry error'): np.float64(0.03003),
# ...

# %%
# %pip install requests
# %pip install pandas

import os
import requests
import numpy as np
import pandas as pd
import json

def create_tf_serving_json(data):
    return {'inputs': {name: data[name].tolist() for name in data.keys()} if isinstance(data, dict) else data.tolist()}

def score_model(dataset):
    url = 'https://dbc-626dd028-c0fe.cloud.databricks.com/serving-endpoints/optuna_trial_6/invocations'
    headers = {'Authorization': f'Bearer {token}', 'Content-Type': 'application/json'}
    ds_dict = {'dataframe_split': dataset.to_dict(orient='split')} if isinstance(dataset, pd.DataFrame) else create_tf_serving_json(dataset)
    data_json = json.dumps(ds_dict, allow_nan=True)
    response = requests.request(method='POST', headers=headers, url=url, data=data_json)
    if response.status_code != 200:
        raise Exception(f'Request failed with status {response.status_code}, {response.text}')
    return response.json()
# Out:
# ...
#
# [notice] A new release of pip available: 22.3.1 -> 26.0.1
# [notice] To update, run: python3.11 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 5.9 MB/s eta 0:00:0000:0100:01
# ...
#
# [notice] A new release of pip available: 22.3.1 -> 26.0.1
# [notice] To update, run: python3.11 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
score_model(row_dict)
# Out:
# {'predictions': [0]}
